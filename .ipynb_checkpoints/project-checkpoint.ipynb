# %%
import pandas as pd

# %%
data1=pd.read_csv('data.csv')
data2=pd.read_csv('hand.csv')
data3=pd.read_csv('coat.csv')
data4=pd.read_csv('jeans.csv')
data5=pd.read_csv('sensor-Beng.csv')

# %%
data5
# Out:
#            time    ax    ay    az  atotal
# 0      0.003133  0.03 -0.01  0.02    0.03
# 1      0.012556 -0.09  0.06 -0.06    0.12
# 2      0.039021  0.06  0.01 -0.06    0.08
# 3      0.040491  0.00  0.00 -0.06    0.06
# 4      0.042172 -0.15  0.11 -0.10    0.21
# ...         ...   ...   ...   ...     ...
# 3880  46.360976 -0.05  0.07 -0.02    0.08
# 3881  46.381693 -0.05  0.05 -0.02    0.07
# 3882  46.382879 -0.05  0.05  0.08    0.10
# 3883  46.385456 -0.02  0.05  0.11    0.12
# 3884  46.387766  0.01  0.04  0.06    0.07
#
# [3885 rows x 5 columns]

# %%
anklex=data1['ax (m/s^2)']
ankley=data1['ay (m/s^2)']
anklez=data1['az (m/s^2)']
ankleT=data1['aT (m/s^2)']

# %%
handx=data2['ax']
handy=data2['ay']
handz=data2['az']
handT=data2['atotal']

# %%
coatx=data3['ax']
coaty=data3['ay']
coatz=data3['az']
coatT=data3['atotal']

# %%
jeansx=data4['ax']
jeansy=data4['ay']
jeansz=data4['az']
jeansT=data4['atotal']

# %%
Bengx=data5['ax']
Bengy=data5['ay']
Bengz=data5['az']
BengT=data5['atotal']

# %%
from scipy import signal
b, a = signal.butter(3, 0.01, btype='lowpass', analog=False)
low_passed = signal.filtfilt(b, a, anklex)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(low_passed)
plt.title('Butterworth filter frequency response')
plt.xlabel('ax (m/s^2)')
plt.ylabel('Amplitude')
plt.xlim(0, 3885)
# Out:
# (0.0, 3885.0)

# %%
b, a = signal.butter(3, 0.01, btype='lowpass', analog=False)
low_passed = signal.filtfilt(b, a, ankley)

# %%
plt.plot(low_passed)
plt.title('Butterworth filter frequency response')
plt.xlabel('ay (m/s^2)')
plt.ylabel('Amplitude')
plt.xlim(0, 43941)
# Out:
# (0.0, 43941.0)

# %%
b, a = signal.butter(3, 0.01, btype='lowpass', analog=False)
low_passed = signal.filtfilt(b, a, anklez)

# %%
plt.plot(low_passed)
plt.title('Butterworth filter frequency response')
plt.xlabel('az (m/s^2)')
plt.ylabel('Amplitude')
plt.xlim(0, 43941)
# Out:
# (0.0, 43941.0)

# %%
from scipy.fft import fft, ifft, fftfreq
type(ax)
type(ay)
# Out:
# pandas.core.series.Series

# %%
b, a = signal.butter(3, 0.01, btype='lowpass', analog=False)
low_passed = signal.filtfilt(b, a, Bengx)
plt.plot(low_passed)
plt.title('Butterworth filter frequency response')
plt.xlabel('ax (m/s^2)')
plt.ylabel('Amplitude')
plt.xlim(0, 3885)
# Out:
# (0.0, 3885.0)

# %%
b, a = signal.butter(3, 0.01, btype='lowpass', analog=False)
low_passed = signal.filtfilt(b, a, Bengy)
plt.plot(low_passed)
plt.title('Butterworth filter frequency response')
plt.xlabel('ay (m/s^2)')
plt.ylabel('Amplitude')
plt.xlim(0, 3885)
# Out:
# (0.0, 3885.0)

# %%
b, a = signal.butter(3, 0.01, btype='lowpass', analog=False)
low_passed = signal.filtfilt(b, a, Bengz)
plt.plot(low_passed)
plt.title('Butterworth filter frequency response')
plt.xlabel('az (m/s^2)')
plt.ylabel('Amplitude')
plt.xlim(0, 3885)
# Out:
# (0.0, 3885.0)

# %%
import numpy as np

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
AX=anklex.to_numpy()
sr=100
X = fft(AX)
freqs = fftfreq(AX.size)
check_freq = freqs[:AX.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[AX.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=100)
filtered_signal = ifft(X)
filtered_signalAX = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(20000,25000)
plt.ylim(-20,20)
# Out:
# [0.00000000e+00 2.27572709e-05 4.55145419e-05 ... 4.99931728e-01
#  4.99954485e-01 4.99977243e-01]
# 21531
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-20.0, 20.0)

# %%
AY=ankley.to_numpy()
sr=100
X = fft(AY)
freqs = fftfreq(AY.size)
check_freq = freqs[:AY.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[AY.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
peaks, _ = find_peaks(filtered_signal, distance=150)
filtered_signal = ifft(X)
filtered_signalAY = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayy,'b')
plt.xlim(20000,25000)
plt.ylim(-20,20)
# Out:
# [0.00000000e+00 2.27572709e-05 4.55145419e-05 ... 4.99931728e-01
#  4.99954485e-01 4.99977243e-01]
# 21531
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-20.0, 20.0)

# %%
AZ=anklez.to_numpy()
sr=100
X = fft(arrayz)
freqs = fftfreq(AZ.size)
check_freq = freqs[:AZ.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[AZ.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
peaks, _ = find_peaks(filtered_signal, distance=200)
filtered_signal = ifft(X)
filtered_signalAZ = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayz,'b')
plt.xlim(20000,25000)
plt.ylim(-20,20)
# Out:
# [0.00000000e+00 2.27572709e-05 4.55145419e-05 ... 4.99931728e-01
#  4.99954485e-01 4.99977243e-01]
# 21531
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-20.0, 20.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
HX=handx.to_numpy()
sr=100
X = fft(AX)
freqs = fftfreq(HX.size)
check_freq = freqs[:HX.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[HX.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=150)
filtered_signal = ifft(X)
filtered_signalHX = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(5000,8000)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 6.86012211e-05 1.37202442e-04 ... 4.99759896e-01
#  4.99828497e-01 4.99897098e-01]
# 7142
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
HY=handy.to_numpy()
sr=100
X = fft(HY)
freqs = fftfreq(HY.size)
check_freq = freqs[:HY.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[HY.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=100)
filtered_signal = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(5000,8000)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 6.86012211e-05 1.37202442e-04 ... 4.99759896e-01
#  4.99828497e-01 4.99897098e-01]
# 7142
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
HZ=handz.to_numpy()
sr=100
X = fft(HZ)
freqs = fftfreq(HZ.size)
check_freq = freqs[:HZ.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[HZ.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=100)
filtered_signal = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(5000,8000)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 6.86012211e-05 1.37202442e-04 ... 4.99759896e-01
#  4.99828497e-01 4.99897098e-01]
# 7142
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
CX=coatx.to_numpy()
sr=100
X = fft(CX)
freqs = fftfreq(CX.size)
check_freq = freqs[:CX.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[CX.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=100)
filtered_signal = ifft(X)
filtered_signalCX = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(3000,6000)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 1.07898144e-04 2.15796288e-04 ... 4.99676306e-01
#  4.99784204e-01 4.99892102e-01]
# 4541
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
CY=coaty.to_numpy()
sr=100
X = fft(CY)
freqs = fftfreq(CY.size)
check_freq = freqs[:CY.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[CY.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=100)
filtered_signal = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(3000,6000)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 1.07898144e-04 2.15796288e-04 ... 4.99676306e-01
#  4.99784204e-01 4.99892102e-01]
# 4541
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
CZ=coatz.to_numpy()
sr=100
X = fft(CZ)
freqs = fftfreq(CZ.size)
check_freq = freqs[:CZ.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[CZ.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=100)
filtered_signal = ifft(X)
filtered_signalCZ = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(3000,6000)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 1.07898144e-04 2.15796288e-04 ... 4.99676306e-01
#  4.99784204e-01 4.99892102e-01]
# 4541
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
JX=jeansx.to_numpy()
sr=100
X = fft(JX)
freqs = fftfreq(JX.size)
check_freq = freqs[:JX.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[JX.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=100)
filtered_signal = ifft(X)
filtered_signalJX = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(0,2202)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 4.54132607e-04 9.08265213e-04 ... 4.98637602e-01
#  4.99091735e-01 4.99545867e-01]
# 1078
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
JY=jeansy.to_numpy()
sr=100
X = fft(JY)
freqs = fftfreq(JY.size)
check_freq = freqs[:JY.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[JY.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=90)
filtered_signal = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(0,2202)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 4.54132607e-04 9.08265213e-04 ... 4.98637602e-01
#  4.99091735e-01 4.99545867e-01]
# 1078
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
JZ=jeansz.to_numpy()
sr=100
X = fft(JZ)
freqs = fftfreq(JZ.size)
check_freq = freqs[:JZ.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[JZ.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=90)
filtered_signal = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(0,2202)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 4.54132607e-04 9.08265213e-04 ... 4.98637602e-01
#  4.99091735e-01 4.99545867e-01]
# 1078
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
BX=Bengx.to_numpy()
sr=100
X = fft(BX)
freqs = fftfreq(BX.size)
check_freq = freqs[:BX.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[BX.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=90)
filtered_signal = ifft(X)
filtered_signalBX = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(0,3885)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 2.57400257e-04 5.14800515e-04 ... 4.99099099e-01
#  4.99356499e-01 4.99613900e-01]
# 1903
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
BY=Bengy.to_numpy()
sr=100
X = fft(BY)
freqs = fftfreq(BY.size)
check_freq = freqs[:BY.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[BY.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=90)
filtered_signal = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(0,3885)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 2.57400257e-04 5.14800515e-04 ... 4.99099099e-01
#  4.99356499e-01 4.99613900e-01]
# 1903
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
from numpy.fft import fft, ifft, fftfreq
import matplotlib.pyplot as plt
BZ=Bengz.to_numpy()
sr=100
X = fft(BZ)
freqs = fftfreq(BZ.size)
check_freq = freqs[:BZ.size//2]
print(check_freq)
count = 0
for i in range(len(check_freq)):
    if check_freq[i] > 0.01:
        X[i] = 0
        X[BZ.size//2+i] = 0
        count += 1
print(count)
N = len(X)
n = np.arange(N)
T = N/sr
freqx = n/T 
#plt.stem(freqx, np.abs(X), 'b', \
         #markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)
from scipy.signal import find_peaks
peaks, _ = find_peaks(filtered_signal, distance=90)
filtered_signal = ifft(X)
plt.plot(filtered_signal,'r')
plt.plot(peaks, filtered_signal[peaks], "x")
#plt.plot(arrayx,'b')
plt.xlim(0,3885)
plt.ylim(-30,30)
# Out:
# [0.00000000e+00 2.57400257e-04 5.14800515e-04 ... 4.99099099e-01
#  4.99356499e-01 4.99613900e-01]
# 1903
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# C:\Users\78227\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-30.0, 30.0)

# %%
frequency=36/((3885)/100)

# %%
stride_length=0.25

# %%
velocity=frequency*stride_length

# %%
velocity
# Out:
# 0.23166023166023164

# %%
position=3885/100*velocity

# %%
position
# Out:
# 9.0

# %%
from scipy import stats
anova = stats.f_oneway(filtered_signalAX,filtered_signalJX,filtered_signalCX,filtered_signalHX)
print(anova)
# Out:
# F_onewayResult(statistic=19.272232837517034, pvalue=1.7341409074364765e-12)

# %%
print(anova.pvalue)
# Out:
# 1.7341409074364765e-12

# %%
anova = stats.f_oneway(filtered_signalAX,filtered_signalJX)
print(anova)
print(anova.pvalue)
# Out:
# F_onewayResult(statistic=6.501643868649928, pvalue=0.01078068390429543)
# 0.01078068390429543

# %%
anova = stats.f_oneway(filtered_signalJX,filtered_signalCX)
print(anova)
print(anova.pvalue)
# Out:
# F_onewayResult(statistic=569.1975716078744, pvalue=8.014203801990273e-123)
# 8.014203801990273e-123

# %%
anova = stats.f_oneway(filtered_signalCX,filtered_signalHX)
print(anova)
print(anova.pvalue)
# Out:
# F_onewayResult(statistic=37.7571661484691, pvalue=8.068837276797991e-10)
# 8.068837276797991e-10

# %%
anova = stats.f_oneway(filtered_signalAX,filtered_signalBX)
print(anova)
print(anova.pvalue)
# Out:
# F_onewayResult(statistic=162.56071962939055, pvalue=3.587408966460683e-37)
# 3.587408966460683e-37
